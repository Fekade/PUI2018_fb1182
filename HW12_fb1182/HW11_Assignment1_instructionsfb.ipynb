# %% [markdown]
# ## Time series clustering exercise
# ## Data
#
# Download the census bureau business data for all years 1993-2014. You can investigate using the API (I have not done it with the census bureau). I did is as you see below
#
# The data is on the github repo. Each file is the economic census for 1 year. Download it programmatically and move it to PUIdata
#
# Download the NYC zipcodes shapefile. One of many ways in which you can get the zipcodes shapefile for NYC https://data.cityofnewyork.us/download/i8iw-xf4u/application%2Fzip
# ## You can use zipfile module in python to unzip the files
#
# it should be installed in your system, but if it is not you can get the code with wget from here https://github.com/python/cpython/blob/2.7/Lib/zipfile.py remembering to use the raw link (or you can use the usual shell commands)

# %% [markdown]
# ## Data cleaning
#
# you may need to clean your data: for some NYC zip codes there may be no info sanity check: you should have 20 (N_timestamps) datapoints per time series and about 250 zipcodes (Nzipcodes)
#
# IMPORTANT: read the instructions below on pre-processing. Afte rthat:
#
# mydata.shape should be (Nzipcodes, Ntimestamps)
#
# mydata[i].std() shoould be 1 for all i in range(len(Nzipcodes))
#
# mydata[i].mean() should be ~0 for all i in range(len(Nzipcodes))
# ## TASKS:
#
# 1. get and prep your data.
# 2. cluster the NUMBER OF ESTABLISHMENTS time series with K-means
# in **a few** clusters (as discussed there is no real good, sound way to
# decide what a good number is here. try a few options, keeping in mind
# a few is more than a couple, but i recommand you stay within the
# single digit numbers)
#
# 3. plot the cluster centers (if you used K means those are the means of
# the clusters). you can plot for example the cluster centers overlayed on
# each time series (using the alpha channel to control the opacity in the
# plot may be helpful here).
#
# 4. Use another clustering algorithm (of your choice)
#
# 5. overlay your data on a NYC map: you can use shapefiles for the
# zip codes and different colors for different clusters
#
# 6. Compare the results of the 2 algorithms
#
# 7. attempt an interpretation. this is dangerous ground: clustering is
# an exploratory tool so you do not want to jump to conclusions because
# you see some clusters! but seeing structure in your data can inform
# your next moves as an investigator.
#
# Note on preprocessing: the preparation of these data should include the "standardization" of the time seris. Always when you apply a moachine learning model you should standardize the data or whiten it. These operations may be complicated preprocessing operation, they can for example invoke PCA, and they are aimed at removing covariance in the feature space.
#
# The simplest version of whitening standardizes each feature" from every column (feature) you subtract the mean and you divide it by the standard deviation.
#
# But the time series preprocessing is different if you want to use each time stamp as feature: because you want to maintain the coherence of the data, i.e. you **do not want** to treat each feature as an independent feature! the pattenrs in the time series are what you are clustering on (time series goes up and down, creating a pattern) and those patterns would be lost by whitening.
#
# #### So when you cluster or otherwise use a time series in a model, using each timestamp as a feature, you want to standardize the observations, not the features.
#
# From each row of your table (observation, in this case each zipcode) subtract the mean and you divide the row by the standard deviation.

# %%
# !wget https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp{00..14}totals.zip?raw=true
# Out:
# --2018-12-13 03:50:41--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp00totals.zip?raw=true
# Resolving github.com (github.com)... 192.30.253.113, 192.30.253.112
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp00totals.zip [following]
# --2018-12-13 03:50:41--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp00totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp00totals.zip [following]
# --2018-12-13 03:50:42--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp00totals.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.208.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 628434 (614K) [application/zip]
# Saving to: ‘zbp00totals.zip?raw=true’
#
# zbp00totals.zip?raw 100%[===================>] 613.71K  2.33MB/s    in 0.3s
#
# 2018-12-13 03:50:42 (2.33 MB/s) - ‘zbp00totals.zip?raw=true’ saved [628434/628434]
#
# --2018-12-13 03:50:42--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp01totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp01totals.zip [following]
# --2018-12-13 03:50:42--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp01totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp01totals.zip [following]
# --2018-12-13 03:50:42--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp01totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 628815 (614K) [application/zip]
# Saving to: ‘zbp01totals.zip?raw=true’
#
# zbp01totals.zip?raw 100%[===================>] 614.08K  2.39MB/s    in 0.3s
#
# 2018-12-13 03:50:43 (2.39 MB/s) - ‘zbp01totals.zip?raw=true’ saved [628815/628815]
#
# --2018-12-13 03:50:43--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp02totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp02totals.zip [following]
# --2018-12-13 03:50:43--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp02totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp02totals.zip [following]
# --2018-12-13 03:50:43--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp02totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 620754 (606K) [application/zip]
# Saving to: ‘zbp02totals.zip?raw=true’
#
# zbp02totals.zip?raw 100%[===================>] 606.21K  2.22MB/s    in 0.3s
#
# 2018-12-13 03:50:43 (2.22 MB/s) - ‘zbp02totals.zip?raw=true’ saved [620754/620754]
#
# --2018-12-13 03:50:43--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp03totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp03totals.zip [following]
# --2018-12-13 03:50:44--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp03totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp03totals.zip [following]
# --2018-12-13 03:50:44--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp03totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 622790 (608K) [application/zip]
# Saving to: ‘zbp03totals.zip?raw=true’
#
# zbp03totals.zip?raw 100%[===================>] 608.19K  2.48MB/s    in 0.2s
#
# 2018-12-13 03:50:44 (2.48 MB/s) - ‘zbp03totals.zip?raw=true’ saved [622790/622790]
#
# --2018-12-13 03:50:44--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp04totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp04totals.zip [following]
# --2018-12-13 03:50:44--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp04totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp04totals.zip [following]
# --2018-12-13 03:50:44--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp04totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 625803 (611K) [application/zip]
# Saving to: ‘zbp04totals.zip?raw=true’
#
# zbp04totals.zip?raw 100%[===================>] 611.14K  2.24MB/s    in 0.3s
#
# 2018-12-13 03:50:45 (2.24 MB/s) - ‘zbp04totals.zip?raw=true’ saved [625803/625803]
#
# --2018-12-13 03:50:45--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp05totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp05totals.zip [following]
# --2018-12-13 03:50:45--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp05totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp05totals.zip [following]
# --2018-12-13 03:50:45--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp05totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 627583 (613K) [application/zip]
# Saving to: ‘zbp05totals.zip?raw=true’
#
# zbp05totals.zip?raw 100%[===================>] 612.87K  2.53MB/s    in 0.2s
#
# 2018-12-13 03:50:45 (2.53 MB/s) - ‘zbp05totals.zip?raw=true’ saved [627583/627583]
#
# --2018-12-13 03:50:45--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp06totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp06totals.zip [following]
# --2018-12-13 03:50:46--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp06totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp06totals.zip [following]
# --2018-12-13 03:50:46--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp06totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 629107 (614K) [application/zip]
# Saving to: ‘zbp06totals.zip?raw=true’
#
# zbp06totals.zip?raw 100%[===================>] 614.36K  2.62MB/s    in 0.2s
#
# 2018-12-13 03:50:46 (2.62 MB/s) - ‘zbp06totals.zip?raw=true’ saved [629107/629107]
#
# --2018-12-13 03:50:46--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp07totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp07totals.zip [following]
# --2018-12-13 03:50:46--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp07totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp07totals.zip [following]
# --2018-12-13 03:50:46--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp07totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 667754 (652K) [application/zip]
# Saving to: ‘zbp07totals.zip?raw=true’
#
# zbp07totals.zip?raw 100%[===================>] 652.10K  2.29MB/s    in 0.3s
#
# 2018-12-13 03:50:47 (2.29 MB/s) - ‘zbp07totals.zip?raw=true’ saved [667754/667754]
#
# --2018-12-13 03:50:47--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp08totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp08totals.zip [following]
# --2018-12-13 03:50:47--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp08totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp08totals.zip [following]
# --2018-12-13 03:50:47--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp08totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 663242 (648K) [application/zip]
# Saving to: ‘zbp08totals.zip?raw=true’
#
# zbp08totals.zip?raw 100%[===================>] 647.70K  2.39MB/s    in 0.3s
#
# 2018-12-13 03:50:47 (2.39 MB/s) - ‘zbp08totals.zip?raw=true’ saved [663242/663242]
#
# --2018-12-13 03:50:47--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp09totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp09totals.zip [following]
# --2018-12-13 03:50:48--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp09totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp09totals.zip [following]
# --2018-12-13 03:50:48--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp09totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 660109 (645K) [application/zip]
# Saving to: ‘zbp09totals.zip?raw=true’
#
# zbp09totals.zip?raw 100%[===================>] 644.64K  2.28MB/s    in 0.3s
#
# 2018-12-13 03:50:48 (2.28 MB/s) - ‘zbp09totals.zip?raw=true’ saved [660109/660109]
#
# --2018-12-13 03:50:48--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp10totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp10totals.zip [following]
# --2018-12-13 03:50:48--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp10totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp10totals.zip [following]
# --2018-12-13 03:50:48--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp10totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 797534 (779K) [application/zip]
# Saving to: ‘zbp10totals.zip?raw=true’
#
# zbp10totals.zip?raw 100%[===================>] 778.84K  2.39MB/s    in 0.3s
#
# 2018-12-13 03:50:49 (2.39 MB/s) - ‘zbp10totals.zip?raw=true’ saved [797534/797534]
#
# --2018-12-13 03:50:49--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp11totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp11totals.zip [following]
# --2018-12-13 03:50:49--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp11totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp11totals.zip [following]
# --2018-12-13 03:50:49--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp11totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 795390 (777K) [application/zip]
# Saving to: ‘zbp11totals.zip?raw=true’
#
# zbp11totals.zip?raw 100%[===================>] 776.75K  2.41MB/s    in 0.3s
#
# 2018-12-13 03:50:50 (2.41 MB/s) - ‘zbp11totals.zip?raw=true’ saved [795390/795390]
#
# --2018-12-13 03:50:50--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp12totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp12totals.zip [following]
# --2018-12-13 03:50:50--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp12totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp12totals.zip [following]
# --2018-12-13 03:50:50--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp12totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733541 (716K) [application/zip]
# Saving to: ‘zbp12totals.zip?raw=true’
#
# zbp12totals.zip?raw 100%[===================>] 716.35K  2.44MB/s    in 0.3s
#
# 2018-12-13 03:50:50 (2.44 MB/s) - ‘zbp12totals.zip?raw=true’ saved [733541/733541]
#
# --2018-12-13 03:50:50--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp13totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp13totals.zip [following]
# --2018-12-13 03:50:51--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp13totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp13totals.zip [following]
# --2018-12-13 03:50:51--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp13totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733605 (716K) [application/zip]
# Saving to: ‘zbp13totals.zip?raw=true’
#
# zbp13totals.zip?raw 100%[===================>] 716.41K  2.20MB/s    in 0.3s
#
# 2018-12-13 03:50:51 (2.20 MB/s) - ‘zbp13totals.zip?raw=true’ saved [733605/733605]
#
# --2018-12-13 03:50:51--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp14totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp14totals.zip [following]
# --2018-12-13 03:50:51--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp14totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp14totals.zip [following]
# --2018-12-13 03:50:51--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp14totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 733763 (717K) [application/zip]
# Saving to: ‘zbp14totals.zip?raw=true’
#
# zbp14totals.zip?raw 100%[===================>] 716.57K  2.62MB/s    in 0.3s
#
# 2018-12-13 03:50:52 (2.62 MB/s) - ‘zbp14totals.zip?raw=true’ saved [733763/733763]
#
# FINISHED --2018-12-13 03:50:52--
# Total wall clock time: 11s
# Downloaded: 15 files, 9.7M in 4.1s (2.38 MB/s)

# %%
# !wget https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp{94..99}totals.zip?raw=true
# Out:
# --2018-12-13 03:50:59--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp94totals.zip?raw=true
# Resolving github.com (github.com)... 192.30.253.112, 192.30.253.113
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp94totals.zip [following]
# --2018-12-13 03:50:59--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp94totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp94totals.zip [following]
# --2018-12-13 03:50:59--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp94totals.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.208.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 611524 (597K) [application/zip]
# Saving to: ‘zbp94totals.zip?raw=true’
#
# zbp94totals.zip?raw 100%[===================>] 597.19K  1.22MB/s    in 0.5s
#
# 2018-12-13 03:51:00 (1.22 MB/s) - ‘zbp94totals.zip?raw=true’ saved [611524/611524]
#
# --2018-12-13 03:51:00--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp95totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp95totals.zip [following]
# --2018-12-13 03:51:00--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp95totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp95totals.zip [following]
# --2018-12-13 03:51:00--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp95totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 625328 (611K) [application/zip]
# Saving to: ‘zbp95totals.zip?raw=true’
#
# zbp95totals.zip?raw 100%[===================>] 610.67K  1.07MB/s    in 0.6s
#
# 2018-12-13 03:51:01 (1.07 MB/s) - ‘zbp95totals.zip?raw=true’ saved [625328/625328]
#
# --2018-12-13 03:51:01--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp96totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp96totals.zip [following]
# --2018-12-13 03:51:01--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp96totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp96totals.zip [following]
# --2018-12-13 03:51:01--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp96totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 632625 (618K) [application/zip]
# Saving to: ‘zbp96totals.zip?raw=true’
#
# zbp96totals.zip?raw 100%[===================>] 617.80K  1.32MB/s    in 0.5s
#
# 2018-12-13 03:51:02 (1.32 MB/s) - ‘zbp96totals.zip?raw=true’ saved [632625/632625]
#
# --2018-12-13 03:51:02--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp97totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp97totals.zip [following]
# --2018-12-13 03:51:02--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp97totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp97totals.zip [following]
# --2018-12-13 03:51:02--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp97totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 629368 (615K) [application/zip]
# Saving to: ‘zbp97totals.zip?raw=true’
#
# zbp97totals.zip?raw 100%[===================>] 614.62K  2.26MB/s    in 0.3s
#
# 2018-12-13 03:51:03 (2.26 MB/s) - ‘zbp97totals.zip?raw=true’ saved [629368/629368]
#
# --2018-12-13 03:51:03--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp98totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp98totals.zip [following]
# --2018-12-13 03:51:03--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp98totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp98totals.zip [following]
# --2018-12-13 03:51:03--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp98totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 617784 (603K) [application/zip]
# Saving to: ‘zbp98totals.zip?raw=true’
#
# zbp98totals.zip?raw 100%[===================>] 603.30K  2.02MB/s    in 0.3s
#
# 2018-12-13 03:51:03 (2.02 MB/s) - ‘zbp98totals.zip?raw=true’ saved [617784/617784]
#
# --2018-12-13 03:51:03--  https://github.com/fedhere/PUI2018_fb55/blob/master/HW12_fb55/zbp99totals.zip?raw=true
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp99totals.zip [following]
# --2018-12-13 03:51:04--  https://github.com/fedhere/PUI2018_fb55/raw/master/HW12_fb55/zbp99totals.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp99totals.zip [following]
# --2018-12-13 03:51:04--  https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW12_fb55/zbp99totals.zip
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.208.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 625814 (611K) [application/zip]
# Saving to: ‘zbp99totals.zip?raw=true’
#
# zbp99totals.zip?raw 100%[===================>] 611.15K  2.52MB/s    in 0.2s
#
# 2018-12-13 03:51:04 (2.52 MB/s) - ‘zbp99totals.zip?raw=true’ saved [625814/625814]
#
# FINISHED --2018-12-13 03:51:04--
# Total wall clock time: 5.5s
# Downloaded: 6 files, 3.6M in 2.3s (1.56 MB/s)

# %%
import pandas as pd
import zipfile
import os
import geopandas as gpd
import numpy as np
import zipfile 
import glob
from sklearn import cluster, datasets
import sklearn
#import shutil
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import pylab as pl
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn import preprocessing
from functools import reduce
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster as scp

# %%
os.environ["PUIDATA"] = '%s/PUIdata'%os.getenv("HOME")
os.chdir(os.getenv("PUIDATA"))
#os.getcwd()

# %%
# renaming all zip files from zbpfiles;
for fname in glob.glob('*raw=true'):
    os.rename(fname, fname[:15])

# %%
# !wget https://data.cityofnewyork.us/download/i8iw-xf4u/application%2Fzip -O NYCZipcode.zip
# Out:
# --2018-12-13 03:51:26--  https://data.cityofnewyork.us/download/i8iw-xf4u/application%2Fzip
# Resolving data.cityofnewyork.us (data.cityofnewyork.us)... 52.206.68.26, 52.206.140.205, 52.206.140.199
# Connecting to data.cityofnewyork.us (data.cityofnewyork.us)|52.206.68.26|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.cityofnewyork.us/api/views/i8iw-xf4u/files/YObIR0MbpUVA0EpQzZSq5x55FzKGM2ejSeahdvjqR20?filename=ZIP_CODE_040114.zip [following]
# --2018-12-13 03:51:26--  https://data.cityofnewyork.us/api/views/i8iw-xf4u/files/YObIR0MbpUVA0EpQzZSq5x55FzKGM2ejSeahdvjqR20?filename=ZIP_CODE_040114.zip
# Reusing existing connection to data.cityofnewyork.us:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘NYCZipcode.zip’
#
# NYCZipcode.zip          [    <=>             ]   1.44M  1.97MB/s    in 0.7s
#
# 2018-12-13 03:51:27 (1.97 MB/s) - ‘NYCZipcode.zip’ saved [1514401]

# %%
# !unzip NYCZipcode.zip
# Out:
# Archive:  NYCZipcode.zip
# replace ZIP_CODE_040114.shx? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
nyczipsshp = gpd.GeoDataFrame.from_file(os.getenv("PUIDATA") + "/ZIP_CODE_040114.shp")

# %%
print("ZIPCODES:",
      len(np.unique(nyczipsshp.ZIPCODE)), "POLYGONS:",
      len(nyczipsshp.ZIPCODE),
      "the difference is due to island with same zip as parts of land,",
      "but disjoint shapes")
nyczips = nyczipsshp.ZIPCODE.values.astype(int)
print("number of NYC zip codes:", len(nyczips))
# Out:
# ZIPCODES: 248 POLYGONS: 263 the difference is due to island with same zip as parts of land, but disjoint shapes
# number of NYC zip codes: 263

# %%
columns1 = ['19' + str(z) for z in range(94,100)]
columns2 = ['200' + str(z) for z in range(0,10)]
columns3 = [ '20' + str(z) for z in range(10, 15)]
columns = columns1 + columns2 + columns3

# %%
columns[:3]
# Out:
# ['1994', '1995', '1996']

# %%
zbpfiles = glob.glob('zbp*.zip')

# %%
zbpfiles[:3]
# Out:
# ['zbp04totals.zip', 'zbp96totals.zip', 'zbp01totals.zip']

# %%
for fname in zbpfiles:
    df = pd.read_csv(zipfile.ZipFile(fname).open(fname.replace('.zip', '.txt')))
    print(fname); print(df.head())
# Out:
# zbp04totals.zip
#     zip            name empflag   emp    qp1      ap  est
# 0   501  HOLTSVILLE, NY     NaN    34    170     773    8
# 1  1001      AGAWAM, MA     NaN  8650  61626  279815  500
# 2  1002     AMHERST, MA     NaN  6827  41882  180175  584
# 3  1003     AMHERST, MA     NaN   283    971    4196   15
# 4  1004     AMHERST, MA     NaN   178   1122    4311   43
# zbp96totals.zip
#     zip             name empflag   emp    qp1      ap  est
# 0   501   Holtsville, NY       B     0      0       0    4
# 1  1000  Springfield, MA     NaN   161   1494    6671   11
# 2  1001       Agawam, MA     NaN  6130  37746  171045  433
# 3  1002      Amherst, MA     NaN  6441  32964  141756  487
# 4  1003      Amherst, MA     NaN    77    364    1686   13
# zbp01totals.zip
#     ZIP            NAME EMPFLAG   EMP    QP1      AP  EST
# 0   501  HOLTSVILLE, NY       B     0      0       0    6
# 1  1001      AGAWAM, MA     NaN  8522  64404  270625  490
# 2  1002     AMHERST, MA     NaN  6955  42682  182632  587
# 3  1003     AMHERST, MA     NaN   175    629    2811   13
# 4  1004     AMHERST, MA     NaN   224   1104    4723   37
# zbp08totals.zip
#     zip            name empflag emp_nf    emp qp1_nf    qp1 ap_nf      ap  est
# 0   501  HOLTSVILLE, NY       B      D      0      D      0     D       0    3
# 1  1001      AGAWAM, MA     NaN      G   9681      G  76511     G  340969  477
# 2  1002     AMHERST, MA     NaN      G  13152      G  79481     G  330150  584
# 3  1003     AMHERST, MA     NaN      G    154      H   1076     G    4734   17
# 4  1004     AMHERST, MA     NaN      H    187      S      0     H    6027   18
# zbp10totals.zip
#     zip            name empflag emp_nf    emp qp1_nf    qp1 ap_nf      ap  \
# 0   501  HOLTSVILLE, NY       A      D      0      D      0     D       0
# 1  1001      AGAWAM, MA     NaN      G   9185      G  70693     G  314508
# 2  1002     AMHERST, MA     NaN      G  15633      G  82069     G  351589
# 3  1003     AMHERST, MA     NaN      G    168      H   1297     H    5761
# 4  1004     AMHERST, MA     NaN      H    189      H   1710     H    7241
#
#    est        city stabbr   cty_name
# 0    2  HOLTSVILLE     NY    SUFFOLK
# 1  448      AGAWAM     MA    HAMPDEN
# 2  570     AMHERST     MA  HAMPSHIRE
# 3   16     AMHERST     MA  HAMPSHIRE
# 4   21     AMHERST     MA  HAMPSHIRE
# zbp05totals.zip
#     zip            name empflag    emp    qp1      ap  est
# 0   501  HOLTSVILLE, NY       B      0      0       0    2
# 1  1001      AGAWAM, MA       I      0      0       0  509
# 2  1002     AMHERST, MA     NaN   6691  43876  192996  589
# 3  1003     AMHERST, MA     NaN    115    582    2631   12
# 4  1004     AMHERST, MA     NaN  10356   7958   46893   31
# zbp03totals.zip
#     zip            name empflag   emp    qp1      ap  est
# 0   501  HOLTSVILLE, NY       B     0      0       0    7
# 1  1001      AGAWAM, MA     NaN  8448  61611  271048  505
# 2  1002     AMHERST, MA     NaN  6771  40259  171869  586
# 3  1003     AMHERST, MA     NaN   258   1142    4745   16
# 4  1004     AMHERST, MA     NaN   146    972    4003   21
# zbp97totals.zip
#     zip             name empflag   emp    qp1      ap  est
# 0   501   HOLTSVILLE, NY     NaN    47    168     523    4
# 1  1000  SPRINGFIELD, MA       E     0      0       0    8
# 2  1001       AGAWAM, MA     NaN  6900  44201  196588  457
# 3  1002      AMHERST, MA     NaN  6328  37558  154955  500
# 4  1003      AMHERST, MA     NaN    90    448    2122   15
# zbp99totals.zip
#     ZIP            NAME EMPFLAG   EMP    QP1      AP  EST
# 0   501  HOLTSVILLE, NY       B     0      0       0    2
# 1  1001      AGAWAM, MA     NaN  7786  58129  252624  469
# 2  1002     AMHERST, MA     NaN  6607  36220  163105  558
# 3  1003     AMHERST, MA     NaN    82    336    1646   13
# 4  1004     AMHERST, MA     NaN   600   2659   10426   35
# zbp07totals.zip
#     zip            name empflag emp_nf    emp qp1_nf    qp1 ap_nf      ap  est
# 0   501  HOLTSVILLE, NY       B      D      0      D      0     D       0    5
# 1  1001      AGAWAM, MA     NaN      G   9663      G  78154     G  333829  503
# 2  1002     AMHERST, MA     NaN      G  12635      G  73904     G  311951  596
# 3  1003     AMHERST, MA     NaN      H    141      H   1063     H    4377   16
# 4  1004     AMHERST, MA       C      S      0      H   1254     H    5141   20
# zbp13totals.zip
#     zip            name empflag emp_nf    emp qp1_nf    qp1 ap_nf      ap  \
# 0   501  HOLTSVILLE, NY       A      D      0      D      0     D       0
# 1  1001      AGAWAM, MA     NaN      G   9418      G  92083     G  373116
# 2  1002     AMHERST, MA     NaN      H  17263      G  95047     G  398992
# 3  1003     AMHERST, MA     NaN      G    184      H   1754     H    7181
# 4  1004     AMHERST, MA     NaN      H    179      H   1168     H    5019
#
#    est        city stabbr   cty_name
# 0    2  HOLTSVILLE     NY    SUFFOLK
# 1  439      AGAWAM     MA    HAMPDEN
# 2  572     AMHERST     MA  HAMPSHIRE
# 3   15     AMHERST     MA  HAMPSHIRE
# 4   16     AMHERST     MA  HAMPSHIRE
# zbp09totals.zip
#     zip            name empflag emp_nf    emp qp1_nf    qp1 ap_nf      ap  est
# 0   501  HOLTSVILLE, NY       A      D      0      D      0     D       0    2
# 1  1001      AGAWAM, MA     NaN      G   9950      G  72700     G  318373  458
# 2  1002     AMHERST, MA     NaN      G  13729      G  86730     G  350310  571
# 3  1003     AMHERST, MA     NaN      G    212      H   1656     H    5684   16
# 4  1004     AMHERST, MA     NaN      H    182      H   1436     H    6412   18
# zbp12totals.zip
#     zip            name empflag emp_nf    emp qp1_nf    qp1 ap_nf      ap  \
# 0   501  HOLTSVILLE, NY       A      D      0      D      0     D       0
# 1  1001      AGAWAM, MA     NaN      G   9033      G  84256     G  356861
# 2  1002     AMHERST, MA     NaN      H  16422      G  90914     G  378362
# 3  1003     AMHERST, MA     NaN      G    199      G   2003     G    8009
# 4  1004     AMHERST, MA     NaN      H    161      H   1140     H    5107
#
#    est        city stabbr   cty_name
# 0    2  HOLTSVILLE     NY    SUFFOLK
# 1  453      AGAWAM     MA    HAMPDEN
# 2  572     AMHERST     MA  HAMPSHIRE
# 3   15     AMHERST     MA  HAMPSHIRE
# 4   16     AMHERST     MA  HAMPSHIRE
# zbp00totals.zip
#     ZIP            NAME EMPFLAG   EMP    QP1      AP  EST
# 0   501  HOLTSVILLE, NY       A     0      0       0    1
# 1  1001      AGAWAM, MA     NaN  8042  59833  259661  493
# 2  1002     AMHERST, MA     NaN  6547  36719  169658  563
# 3  1003     AMHERST, MA     NaN    82    308    2482   13
# 4  1004     AMHERST, MA     NaN   717   2049    5826   48
# zbp11totals.zip
#     zip            name empflag emp_nf    emp qp1_nf    qp1 ap_nf      ap  \
# 0   501  HOLTSVILLE, NY       A      D      0      D      0     D       0
# 1  1001      AGAWAM, MA     NaN      G   8788      G  75093     G  322008
# 2  1002     AMHERST, MA     NaN      G  15878      G  84225     G  360685
# 3  1003     AMHERST, MA     NaN      G    198      H   2054     H    8591
# 4  1004     AMHERST, MA       C      S      0      H   1578     H    7063
#
#    est        city stabbr   cty_name
# 0    2  HOLTSVILLE     NY    SUFFOLK
# 1  436      AGAWAM     MA    HAMPDEN
# 2  558     AMHERST     MA  HAMPSHIRE
# 3   16     AMHERST     MA  HAMPSHIRE
# 4   19     AMHERST     MA  HAMPSHIRE
# zbp06totals.zip
#     zip            name empflag   emp    qp1      ap  est
# 0   501  HOLTSVILLE, NY     NaN    39    216     979    8
# 1  1001      AGAWAM, MA     NaN  9564  73282  328021  509
# 2  1002     AMHERST, MA     NaN  6977  49260  211677  582
# 3  1003     AMHERST, MA     NaN   123    698    3156   12
# 4  1004     AMHERST, MA     NaN   276   1464    5038   30
# zbp98totals.zip
#     ZIP            NAME EMPFLAG   EMP    QP1      AP  EST
# 0   501  HOLTSVILLE, NY     NaN     2     11      57    3
# 1  1001      AGAWAM, MA     NaN  7121  47926  215641  444
# 2  1002     AMHERST, MA     NaN  6278  34435  154135  490
# 3  1003     AMHERST, MA     NaN    86    535    2301   14
# 4  1004     AMHERST, MA     NaN   172    811    4043   31
# zbp14totals.zip
#     zip            name empflag emp_nf    emp qp1_nf    qp1 ap_nf      ap  \
# 0   501  HOLTSVILLE, NY       B      D      0      D      0     D       0
# 1  1001      AGAWAM, MA     NaN      G   9110      G  88574     G  364418
# 2  1002     AMHERST, MA     NaN      H  17513      G  99432     G  421772
# 3  1003     AMHERST, MA     NaN      G    227      H   1911     H    8026
# 4  1004     AMHERST, MA       C      S      0      S      0     H    4921
#
#    est        city stabbr   cty_name
# 0    4  HOLTSVILLE     NY    SUFFOLK
# 1  458      AGAWAM     MA    HAMPDEN
# 2  560     AMHERST     MA  HAMPSHIRE
# 3   18     AMHERST     MA  HAMPSHIRE
# 4   13     AMHERST     MA  HAMPSHIRE
# zbp02totals.zip
#     ZIP            NAME EMPFLAG   EMP    QP1      AP  EST
# 0   501  HOLTSVILLE, NY     NaN    40    148     660   11
# 1  1001      AGAWAM, MA       I     0      0       0  490
# 2  1002     AMHERST, MA     NaN  6866  39616  170725  566
# 3  1003     AMHERST, MA     NaN   268   1097    3900   15
# 4  1004     AMHERST, MA     NaN   169   1015    4032   23
# zbp95totals.zip
#     zip             name empflag   emp    qp1      ap  est
# 0   501   Holtsville, NY       B     0      0       0    2
# 1  1000  Springfield, MA     NaN    49    529    2127    4
# 2  1001       Agawam, MA     NaN  5920  32993  152512  439
# 3  1002      Amherst, MA     NaN  6153  31645  132699  467
# 4  1003      Amherst, MA     NaN    89    380    1698   10
# zbp94totals.zip
#     zip         name empflag   emp    qp1      ap  est
# 0  1001   Agawam, MA     NaN  6198  33601  155158  439
# 1  1002  Amherst, MA     NaN  6073  28924  127367  450
# 2  1003  Amherst, MA     NaN    68    367    1604   10
# 3  1004  Amherst, MA     NaN   210    844    4302   47
# 4  1005    Barre, MA     NaN   678   3010   13521   92

# %%
df = [pd.read_csv(zipfile.ZipFile(fname).open(fname.replace('.zip', '.txt'))) for fname in zbpfiles]

# %%
for i in range(len(zbpfiles)):
    df[i].columns = [x.lower() for x in df[i].columns]

# %%
df_ = [df[['zip','est']] for df in df]

# %%
# we want to get the number of establishments every year and we need the zipcode
for i in range(len(zbpfiles)):
    df_[i] = df_[i].rename(columns={'est': columns[i]})

# %%
#df_

# %%
dff = reduce(lambda x, y: pd.merge(x, y, on = 'zip', how='inner'), df_)

# %%
dff.head()
# Out:
#     zip  1994  1995  1996  1997  1998  1999  2000  2001  2002  ...   2005  \
# 0  1001   500   433   490   477   448   509   505   457   469  ...    458
# 1  1002   584   487   587   584   570   589   586   500   558  ...    571
# 2  1003    15    13    13    17    16    12    16    15    13  ...     16
# 3  1004    43    47    37    18    21    31    21    41    35  ...     18
# 4  1005    97   101    90    97    96    94    93   104    82  ...     87
#
#    2006  2007  2008  2009  2010  2011  2012  2013  2014
# 0   453   493   436   509   444   458   490   439   439
# 1   572   563   558   582   490   560   566   467   450
# 2    15    13    16    12    14    18    15    10    10
# 3    16    48    19    30    31    13    23    48    47
# 4    94    86    91    98    95    97    94    95    92
#
# [5 rows x 22 columns]

# %%
nyczipsshp.head()
# Out:
#   ZIPCODE BLDGZIP   PO_NAME  POPULATION          AREA STATE  COUNTY ST_FIPS  \
# 0   11436       0   Jamaica     18681.0  2.269930e+07    NY  Queens      36
# 1   11213       0  Brooklyn     62426.0  2.963100e+07    NY   Kings      36
# 2   11212       0  Brooklyn     83866.0  4.197210e+07    NY   Kings      36
# 3   11225       0  Brooklyn     56527.0  2.369863e+07    NY   Kings      36
# 4   11218       0  Brooklyn     72280.0  3.686880e+07    NY   Kings      36
#
#   CTY_FIPS                   URL  SHAPE_AREA  SHAPE_LEN  \
# 0      081  http://www.usps.com/         0.0        0.0
# 1      047  http://www.usps.com/         0.0        0.0
# 2      047  http://www.usps.com/         0.0        0.0
# 3      047  http://www.usps.com/         0.0        0.0
# 4      047  http://www.usps.com/         0.0        0.0
#
#                                             geometry
# 0  POLYGON ((1038098.251871482 188138.3800067157,...
# 1  POLYGON ((1001613.712964058 186926.4395172149,...
# 2  POLYGON ((1011174.275535807 183696.33770971, 1...
# 3  POLYGON ((995908.3654508889 183617.6128015518,...
# 4  POLYGON ((991997.1134308875 176307.4958601296,...

# %%
# selecting columns of interest before merging with shapefile
NYCzip = nyczipsshp[['ZIPCODE', 'geometry']]
NYCzip.columns = [['zip', 'geometry']]

# %%
# We would like to use the zip column to merge with our geodataframe for NYC;
# but we see that some of the dataframes have zip for this specific column and other times it is ZIP;
# let's make that uniform; so this line is getting into the above cell;
NYCzip.columns = NYCzip.columns.map('_'.join) # strangely columns were coming in form of tuples had to change them to str
NYCzip.columns
# Out:
# Index(['zip', 'geometry'], dtype='object')

# %%
# before merging we make sure the two columns on which merging happens are of the same dtype;
NYCzip.zip = NYCzip.zip.astype(int)
NYCzip.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 2 columns):
# zip         263 non-null int64
# geometry    263 non-null object
# dtypes: int64(1), object(1)
# memory usage: 4.2+ KB
# /home/habtemariam/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
NYCzip.head()
# Out:
#      zip                                           geometry
# 0  11436  POLYGON ((1038098.251871482 188138.3800067157,...
# 1  11213  POLYGON ((1001613.712964058 186926.4395172149,...
# 2  11212  POLYGON ((1011174.275535807 183696.33770971, 1...
# 3  11225  POLYGON ((995908.3654508889 183617.6128015518,...
# 4  11218  POLYGON ((991997.1134308875 176307.4958601296,...

# %%
NYCzip.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 2 columns):
# zip         263 non-null int64
# geometry    263 non-null object
# dtypes: int64(1), object(1)
# memory usage: 4.2+ KB

# %%
NYC = pd.merge(NYCzip, dff, on='zip', how='inner')

# %%
NYC.head()
# Out:
#      zip                                           geometry  1994  1995  1996  \
# 0  11436  POLYGON ((1038098.251871482 188138.3800067157,...    84    53    57
# 1  11213  POLYGON ((1001613.712964058 186926.4395172149,...   570   433   493
# 2  11212  POLYGON ((1011174.275535807 183696.33770971, 1...   586   502   527
# 3  11225  POLYGON ((995908.3654508889 183617.6128015518,...   492   388   422
# 4  11218  POLYGON ((991997.1134308875 176307.4958601296,...  1295  1049  1180
#
#    1997  1998  1999  2000  2001  ...   2005  2006  2007  2008  2009  2010  \
# 0    90    98    82    74    51  ...     92    95    65   101    80    51
# 1   592   675   556   569   456  ...    621   726   477   674   565   476
# 2   602   699   587   581   527  ...    647   721   520   713   570   519
# 3   520   580   491   488   410  ...    543   623   417   597   499   416
# 4  1397  1474  1332  1247  1075  ...   1457  1605  1161  1523  1331  1118
#
#    2011  2012  2013  2014
# 0   109    78    50    51
# 1   772   546   420   406
# 2   752   577   494   505
# 3   696   479   387   381
# 4  1736  1228  1015   985
#
# [5 rows x 23 columns]

# %%
len(NYC)
# Out:
# 243

# %%
#NYC.info()

# %%
NYC.columns
# Out:
# Index(['zip', 'geometry', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014'],
#       dtype='object')

# %%
# 20 years of data and 263 zipcodes
NYC.shape
# Out:
# (243, 23)

# %%
cleancsb = NYC.set_index('zip')

# %%
cleancsb.head()
# Out:
#                                                 geometry  1994  1995  1996  \
# zip
# 11436  POLYGON ((1038098.251871482 188138.3800067157,...    84    53    57
# 11213  POLYGON ((1001613.712964058 186926.4395172149,...   570   433   493
# 11212  POLYGON ((1011174.275535807 183696.33770971, 1...   586   502   527
# 11225  POLYGON ((995908.3654508889 183617.6128015518,...   492   388   422
# 11218  POLYGON ((991997.1134308875 176307.4958601296,...  1295  1049  1180
#
#        1997  1998  1999  2000  2001  2002  ...   2005  2006  2007  2008  2009  \
# zip                                        ...
# 11436    90    98    82    74    51    58  ...     92    95    65   101    80
# 11213   592   675   556   569   456   473  ...    621   726   477   674   565
# 11212   602   699   587   581   527   541  ...    647   721   520   713   570
# 11225   520   580   491   488   410   409  ...    543   623   417   597   499
# 11218  1397  1474  1332  1247  1075  1149  ...   1457  1605  1161  1523  1331
#
#        2010  2011  2012  2013  2014
# zip
# 11436    51   109    78    50    51
# 11213   476   772   546   420   406
# 11212   519   752   577   494   505
# 11225   416   696   479   387   381
# 11218  1118  1736  1228  1015   985
#
# [5 rows x 22 columns]

# %%
cleancsb.index = cleancsb.index.sort_values()

# %%
cleancsb.head()
# Out:
#                                                 geometry  1994  1995  1996  \
# zip
# 10001  POLYGON ((1038098.251871482 188138.3800067157,...    84    53    57
# 10002  POLYGON ((1001613.712964058 186926.4395172149,...   570   433   493
# 10003  POLYGON ((1011174.275535807 183696.33770971, 1...   586   502   527
# 10004  POLYGON ((995908.3654508889 183617.6128015518,...   492   388   422
# 10004  POLYGON ((991997.1134308875 176307.4958601296,...  1295  1049  1180
#
#        1997  1998  1999  2000  2001  2002  ...   2005  2006  2007  2008  2009  \
# zip                                        ...
# 10001    90    98    82    74    51    58  ...     92    95    65   101    80
# 10002   592   675   556   569   456   473  ...    621   726   477   674   565
# 10003   602   699   587   581   527   541  ...    647   721   520   713   570
# 10004   520   580   491   488   410   409  ...    543   623   417   597   499
# 10004  1397  1474  1332  1247  1075  1149  ...   1457  1605  1161  1523  1331
#
#        2010  2011  2012  2013  2014
# zip
# 10001    51   109    78    50    51
# 10002   476   772   546   420   406
# 10003   519   752   577   494   505
# 10004   416   696   479   387   381
# 10004  1118  1736  1228  1015   985
#
# [5 rows x 22 columns]

# %%
cleancsb.shape
# Out:
# (243, 22)

# %%
for i in range(len(cleancsb)):
    cleancsb.iloc[i,1:] = (cleancsb.iloc[i,1:] - cleancsb.iloc[i,1:].mean()) / cleancsb.iloc[i,1:].std()

# %%
cleancsb.head()
# Out:
#                                                 geometry      1994      1995  \
# zip
# 10001  POLYGON ((1038098.251871482 188138.3800067157,...  0.395415 -1.193568
# 10002  POLYGON ((1001613.712964058 186926.4395172149,...  0.069398 -1.186307
# 10003  POLYGON ((1011174.275535807 183696.33770971, 1... -0.104191 -1.114040
# 10004  POLYGON ((995908.3654508889 183617.6128015518,... -0.046933 -1.149098
# 10004  POLYGON ((991997.1134308875 176307.4958601296,... -0.049486 -1.180649
#
#            1996      1997      1998      1999      2000      2001      2002  \
# zip
# 10001 -0.988538  0.702960  1.113020  0.292900 -0.117160 -1.296083 -0.937280
# 10002 -0.636364  0.271044  1.031799 -0.058923  0.060232 -0.975496 -0.819678
# 10003 -0.813490  0.088161  1.254297 -0.092169 -0.164301 -0.813490 -0.645182
# 10004 -0.788775  0.249804  0.885668 -0.057531 -0.089324 -0.915948 -0.926545
# 10004 -0.578281  0.419533  0.773596  0.120649 -0.270200 -1.061095 -0.720826
#
#          ...         2005      2006      2007      2008      2009      2010  \
# zip      ...
# 10001    ...     0.805475  0.959248 -0.578478  1.266793  0.190385 -1.296083
# 10002    ...     0.536850  1.499252 -0.783015  1.022634  0.023569 -0.792181
# 10003    ...     0.629152  1.518781 -0.897644  1.422605 -0.296543 -0.909666
# 10004    ...     0.493552  1.341371 -0.841764  1.065830  0.027251 -0.852361
# 10004    ...     0.695427  1.375964 -0.665648  0.998909  0.116050 -0.863371
#
#            2011      2012      2013      2014
# zip
# 10001  1.676853  0.087870 -1.347340 -1.296083
# 10002  1.920875 -0.150580 -1.305462 -1.433782
# 10003  1.891464 -0.212389 -1.210216 -1.077974
# 10004  2.115007 -0.184704 -1.159696 -1.223282
# 10004  1.978331 -0.357567 -1.336988 -1.474935
#
# [5 rows x 22 columns]

# %%
cleancsb.describe()
# Out:
#              1994        1995        1996        1997        1998        1999  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.124314   -0.804548   -0.327877    0.310202    0.491133    0.170685
# std      0.657365    0.812842    0.741319    0.560468    0.718749    0.538337
# min     -1.922128   -1.897567   -1.666750   -1.435979   -1.649178   -1.478227
# 25%     -0.159339   -1.319671   -0.760883    0.087489    0.282918   -0.093326
# 50%      0.063610   -1.105014   -0.566623    0.409915    0.744276    0.157177
# 75%      0.375657   -0.697991   -0.112660    0.636179    0.948360    0.467819
# max      3.963718    2.216083    2.705124    1.781514    1.505138    2.285662
#
#              2000        2001        2002        2003     ...            2005  \
# count  243.000000  243.000000  243.000000  243.000000     ...      243.000000
# mean    -0.085442   -0.651203   -0.463980    0.277438     ...        0.360346
# std      0.584720    0.753154    0.774400    0.542232     ...        0.587235
# min     -1.760021   -1.892837   -1.821346   -1.559909     ...       -1.696628
# 25%     -0.379639   -1.090628   -0.929749    0.076569     ...        0.170918
# 50%     -0.131412   -0.926456   -0.732544    0.327569     ...        0.512900
# 75%      0.175459   -0.536456   -0.189823    0.580074     ...        0.690089
# max      2.655893    1.698668    2.143528    2.152288     ...        1.845008
#
#              2006        2007        2008        2009        2010        2011  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.750864   -0.349822    0.569032    0.190658   -0.560743    1.140232
# std      0.924538    0.799265    0.842238    0.540521    0.775382    1.092847
# min     -2.020149   -2.105643   -2.113009   -1.910232   -2.054090   -2.019528
# 25%      0.477327   -0.831585    0.358136   -0.011155   -1.002660    0.778599
# 50%      1.165268   -0.610926    0.917255    0.223560   -0.816361    1.613328
# 75%      1.375872   -0.119517    1.098092    0.513556   -0.349955    1.844668
# max      2.405536    2.576381    1.738911    1.397476    2.040039    3.406371
#
#              2012        2013        2014
# count  243.000000  243.000000  243.000000
# mean    -0.180408   -0.900371   -1.009820
# std      0.553115    0.938837    1.116464
# min     -1.841075   -2.367927   -3.459962
# 25%     -0.463519   -1.470869   -1.645204
# 50%     -0.235929   -1.207515   -1.322172
# 75%     -0.000853   -0.710477   -0.710121
# max      2.144307    2.228009    3.212291
#
# [8 rows x 21 columns]

# %%
NYC.describe()
# Out:
#                 zip         1994         1995         1996         1997  \
# count    243.000000   243.000000   243.000000   243.000000   243.000000
# mean   10697.687243   903.263374   812.234568   865.695473   919.263374
# std      585.251017  1230.366627  1173.207861  1234.064543  1212.799049
# min    10001.000000     5.000000     2.000000     5.000000     2.000000
# 25%    10121.500000   202.500000   178.000000   190.000000   190.000000
# 50%    10464.000000   537.000000   457.000000   491.000000   545.000000
# 75%    11237.500000  1015.000000   937.000000   951.000000  1061.500000
# max    11697.000000  7370.000000  7075.000000  7188.000000  7472.000000
#
#               1998         1999         2000         2001         2002  \
# count   243.000000   243.000000   243.000000   243.000000   243.000000
# mean    937.012346   906.395062   885.600823   832.506173   850.288066
# std    1198.395461  1223.284020  1196.590739  1198.182206  1207.629794
# min       3.000000     3.000000     5.000000     2.000000     2.000000
# 25%     190.500000   191.500000   208.000000   180.000000   185.000000
# 50%     580.000000   536.000000   534.000000   472.000000   482.000000
# 75%    1095.500000  1034.500000   996.000000   940.500000   955.000000
# max    7241.000000  7312.000000  7084.000000  7154.000000  7233.000000
#
#           ...              2005         2006         2007         2008  \
# count     ...        243.000000   243.000000   243.000000   243.000000
# mean      ...        923.489712   964.320988   864.934156   948.156379
# std       ...       1196.968869  1215.016806  1229.229795  1203.064486
# min       ...          2.000000     3.000000     4.000000     2.000000
# 25%       ...        203.000000   186.500000   192.500000   187.000000
# 50%       ...        560.000000   612.000000   490.000000   597.000000
# 75%       ...       1073.000000  1157.000000   953.000000  1115.000000
# max       ...       7305.000000  7235.000000  7317.000000  7227.000000
#
#               2009         2010         2011         2012         2013  \
# count   243.000000   243.000000   243.000000   243.000000   243.000000
# mean    911.337449   843.716049   997.716049   875.000000   801.930041
# std    1230.869951  1208.995347  1236.510051  1196.521024  1170.402664
# min       3.000000     3.000000     4.000000     5.000000     1.000000
# 25%     195.000000   185.500000   179.000000   200.500000   178.000000
# 50%     541.000000   482.000000   638.000000   525.000000   448.000000
# 75%    1019.000000   950.000000  1237.000000   989.500000   903.000000
# max    7415.000000  7254.000000  7369.000000  7141.000000  7088.000000
#
#               2014
# count   243.000000
# mean    786.374486
# std    1142.732854
# min       1.000000
# 25%     169.500000
# 50%     438.000000
# 75%     896.000000
# max    6999.000000
#
# [8 rows x 22 columns]

# %%
len(cleancsb)
# Out:
# 243

# %%
# we can plot the standardized dataframe
pl.figure(figsize=(10,6))
for i in range(len(cleancsb)):
    pl.plot(cleancsb.iloc[i,1:])
pl.xlim('1994','2014')
pl.title('ZIP codes and total establishments per ZIP code, scaled', fontsize=10)
pl.xlabel('Year')
pl.ylabel('Establishments No');

# %%
cleancsb.mean(axis=1)
cleancsb.mean(axis=1).shape
cleancsb.std(axis=1)
cleancsb.std(axis=1).shape
# Out:
# (243,)

# %%
#km = KMeans(n_clusters=nc, random_state=444).fit(vals)
X=np.asarray(cleancsb.iloc[:,1:])
range_n_clusters = [2,3,4,5,6,7,8,9,10]
for n_clusters in range_n_clusters: #try different numbers of clusters
    km = KMeans(n_clusters=n_clusters, random_state=324)
    cluster_labels = km.fit_predict(X)
    #report average Silhouette score
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters ={},".format(n_clusters)+" the average silhouette_score is :{}".format(silhouette_avg))
# Out:
# For n_clusters =2, the average silhouette_score is :0.5721428017763318
# For n_clusters =3, the average silhouette_score is :0.5384936002674022
# For n_clusters =4, the average silhouette_score is :0.49735104320320284
# For n_clusters =5, the average silhouette_score is :0.3238831914694938
# For n_clusters =6, the average silhouette_score is :0.26490051616687854
# For n_clusters =7, the average silhouette_score is :0.2353994389611605
# For n_clusters =8, the average silhouette_score is :0.23526056551215188
# For n_clusters =9, the average silhouette_score is :0.1974273724304935
# For n_clusters =10, the average silhouette_score is :0.14928769189165836

# %% [markdown]
# #### We see that the ideal number is two;

# %%
km.labels_.shape
# Out:
# (243,)

# %%
n_clusters = 5
km = KMeans(n_clusters=n_clusters, random_state=324)
cluster_labels = km.fit_predict(X)

# %%
centroids =km.cluster_centers_

# %%
NYC['clusters'] = cluster_labels

# %%
f, ax = plt.subplots(figsize=(16,9))
NYC.plot(alpha=1.0, linewidth=2, column = 'clusters', cmap = 'OrRd', ax = ax)
plt.title('KMeans Clustering - 5 Clusters')
plt.xlabel('Longitude')
plt.ylabel('Latitude');

# %% [markdown]
# Figure 3:
# cloropleth of cluster centers for 5 k-means clusters of business patterns (number of businesses) at the zipcode level for NYC zipcodes: each color indicates a cluster. The business pattern time series are plotted at the top.

# %% [markdown]
# And if you use hierarchical clustering in scipy you can make a dandrogram it may look like this:

# %%
fig = pl.figure(figsize=(20,15), dpi=200)
pl.ylabel("distance")
ddg = scp.hierarchy.dendrogram(scp.hierarchy.linkage(cleancsb.iloc[:,1:], method='ward'),
                               labels = cluster_labels,
                               leaf_rotation=90.,  # rotates the x axis labels
                               leaf_font_size=12.)  # font size for the x axis labels)
