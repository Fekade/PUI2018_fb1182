# %% [markdown]
# # Imports (compatible for Python 2 and Python 3)

# %%
try:
    import urllib2 as ulib
except ImportError:
    import urllib3 as ulib

try:
    from StringIO import BytesIO as io
except ImportError:
    from io import BytesIO as io

try:
    from urllib import urlencode as urlencode
except ImportError:
    from urllib.parse import urlencode as urlencode
    
try:
    from urllib import urlopen as urlopen
except ImportError:
    from urllib.request import urlopen as urlopen
    
try:
    from urllib2 import HTTPError as HTTPError
except ImportError:
    from urllib.error import HTTPError as HTTPError

import ast
import pandas as pd

# %%
API_URL = 'https://fb55.carto.com:443/api/v2/sql?q='

def queryCartoDB(query, formatting = 'CSV', source = API_URL):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    
    data = urlencode({'format': formatting, 'q': query}).encode("utf-8")
    try:
        response = urlopen(source, data)
        return response.read()
    except HTTPError as e:
        raise (ValueError('\n'.join(ast.literal_eval(e.readline())['error'])))
        
def get_data(query):
    try:
        return pd.read_csv(io(queryCartoDB(query)), sep = ',')
    except ValueError as v:
        print (str(v))

# %%
query = '''SELECT * FROM fb55.citibike; '''
table = get_data(query)
table.head(5)
# Out:
#    the_geom  start_station_name  the_geom_webmercator  field_1  \
# 0       NaN  E 20 St & Park Ave                   NaN      175
# 1       NaN    W 43 St & 10 Ave                   NaN     1159
# 2       NaN   E 6 St & Avenue B                   NaN     2827
# 3       NaN     E 12 St & 3 Ave                   NaN     4961
# 4       NaN     W 41 St & 8 Ave                   NaN     6156
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.987520          1090  2015-02-01 01:23:00+00
# 1               -73.994618           682  2015-02-01 10:55:00+00
# 2               -73.981854           751  2015-02-01 13:59:00+00
# 3               -73.988900           272  2015-02-01 17:28:00+00
# 4               -73.990026           240  2015-02-01 21:36:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-01 01:42:00+00               503         107
# 1  2015-02-01 11:07:00+00               515        1088
# ...

# %%
query = '''SELECT start_station_id FROM fb55.citibike ORDER BY start_station_id ASC; '''

# %%
table = get_data(query)

# %%
table.head(5)
# Out:
#    start_station_id  Unnamed: 1
# 0                72         NaN
# 1                72         NaN
# 2                72         NaN
# 3                72         NaN
# 4                72         NaN

# %%
query = '''SELECT tripduration FROM fb55.citibike ORDER BY tripduration DESC; '''

# %%
table = get_data(query)

# %%
table.head(5)
# Out:
#    tripduration  Unnamed: 1
# 0         43016         NaN
# 1         43013         NaN
# 2         42784         NaN
# 3         41908         NaN
# 4         37665         NaN

# %%
query = '''SELECT * FROM fb55.citibike ORDER BY start_station_id ASC, tripduration DESC; '''

# %%
table = get_data(query)

# %%
table.columns
# Out:
# Index(['the_geom', 'start_station_name', 'the_geom_webmercator', 'field_1',
#        'start_station_longitude', 'tripduration', 'starttime', 'stoptime',
#        'start_station_id', 'cartodb_id', 'start_station_latitude',
#        'end_station_id', 'end_station_name', 'end_station_latitude',
#        'end_station_longitude', 'bikeid', 'usertype', 'birth_year', 'gender'],
#       dtype='object')

# %%
table.head()
# Out:
#    the_geom start_station_name  the_geom_webmercator  field_1  \
# 0       NaN   W 52 St & 11 Ave                   NaN     9115
# 1       NaN   W 52 St & 11 Ave                   NaN     2051
# 2       NaN   W 52 St & 11 Ave                   NaN    40355
# 3       NaN   W 52 St & 11 Ave                   NaN    12996
# 4       NaN   W 52 St & 11 Ave                   NaN    11359
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.993929          2099  2015-02-03 10:28:00+00
# 1               -73.993929          1944  2015-02-01 12:39:00+00
# 2               -73.993929          1914  2015-02-07 09:49:00+00
# 3               -73.993929          1801  2015-02-04 06:32:00+00
# 4               -73.993929          1678  2015-02-03 18:21:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-03 11:02:00+00                72        9054
# 1  2015-02-01 13:12:00+00                72        1983
# ...

# %%
query = '''SELECT * FROM fb55.citibike ORDER BY cartodb_id DESC limit 10; '''

# %%
table = get_data(query)

# %%
table
# Out:
#    the_geom     start_station_name  the_geom_webmercator  field_1  \
# 0       NaN         E 4 St & 2 Ave                   NaN    46199
# 1       NaN     Carmine St & 6 Ave                   NaN    46198
# 2       NaN        5 Ave & E 29 St                   NaN    46197
# 3       NaN        5 Ave & E 29 St                   NaN    46196
# 4       NaN        W 20 St & 8 Ave                   NaN    46195
# 5       NaN        1 Ave & E 44 St                   NaN    46194
# 6       NaN        E 20 St & 2 Ave                   NaN    46193
# 7       NaN  Warren St & Church St                   NaN    46192
# 8       NaN       W 47 St & 10 Ave                   NaN    46191
# 9       NaN        W 17 St & 8 Ave                   NaN    46190
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.989780           917  2015-02-07 23:59:00+00
# 1               -74.002150           548  2015-02-07 23:58:00+00
# ...

# %%
query = '''SELECT DISTINCT birth_year FROM fb55.citibike WHERE birth_year IS NOT NULL limit 10; '''
table = get_data(query)
table
# Out:
#    birth_year  Unnamed: 1
# 0        1972         NaN
# 1        1985         NaN
# 2        1998         NaN
# 3        1941         NaN
# 4        1950         NaN
# 5        1967         NaN
# 6        1991         NaN
# 7        1961         NaN
# 8        1942         NaN
# 9        1984         NaN

# %%
query = '''SELECT MIN(tripduration), MAX(tripduration), AVG(tripduration) FROM fb55.citibike;'''
table = get_data(query)
table
# Out:
#    min    max         avg
# 0   60  43016  675.865823

# %%
query = '''SELECT starttime FROM fb55.citibike WHERE EXTRACT(DAY FROM starttime::DATE) = 1;'''
table = get_data(query)
print(table.head(5))
# Out:
#                 starttime  Unnamed: 1
# 0  2015-02-01 01:23:00+00         NaN
# 1  2015-02-01 10:55:00+00         NaN
# 2  2015-02-01 13:59:00+00         NaN
# 3  2015-02-01 17:28:00+00         NaN
# 4  2015-02-01 21:36:00+00         NaN

# %%
query = ''' SELECT starttime FROM fb55.citibike WHERE EXTRACT(HOUR FROM starttime::TIME) = 1;'''
table = get_data(query)
print(table.head(5))
# Out:
#                 starttime  Unnamed: 1
# 0  2015-02-01 01:23:00+00         NaN
# 1  2015-02-01 01:11:00+00         NaN
# 2  2015-02-06 01:13:00+00         NaN
# 3  2015-02-01 01:03:00+00         NaN
# 4  2015-02-01 01:04:00+00         NaN

# %%
query = '''SELECT starttime FROM fb55.citibike WHERE EXTRACT(HOUR FROM starttime::DATE) IN (0, 1, 2);'''
table = get_data(query)
print(table.head(5))
# Out:
#                 starttime  Unnamed: 1
# 0  2015-02-01 01:23:00+00         NaN
# 1  2015-02-01 10:55:00+00         NaN
# 2  2015-02-01 13:59:00+00         NaN
# 3  2015-02-01 17:28:00+00         NaN
# 4  2015-02-01 21:36:00+00         NaN

# %%
query = '''SELECT AVG(birth_year) FROM fb55.citibike WHERE EXTRACT(HOUR FROM starttime::time) = 2;'''
table = get_data(query)
#print(table.head(5))
table
# Out:
#            avg  Unnamed: 1
# 0  1978.201754         NaN

# %%
query = '''SELECT MAX(2018- birth_year) FROM fb55.citibike WHERE EXTRACT(HOUR FROM starttime::time) = 3;'''
table = get_data(query)
#print(table.head(5))
table
# Out:
#    max  Unnamed: 1
# 0   78         NaN

# %%
query = '''SELECT COUNT(start_station_id) as count FROM fb55.citibike GROUP BY start_station_id ORDER BY count DESC limit 1;'''
table = get_data(query)
#print(table.head(15))
table
# Out:
#    count  Unnamed: 1
# 0    530         NaN

# %%
query = '''SELECT end_station_id, SUM(tripduration) as sum FROM fb55.citibike GROUP BY end_station_id ORDER BY sum DESC limit 3 ;'''
table = get_data(query)
#print(table.head(15))
table
# Out:
#    end_station_id     sum
# 0             477  395161
# 1             521  355829
# 2             318  320525

# %%
query = '''SELECT starttime, start_station_id, AVG(tripduration) as avgduration FROM fb55.citibike 
WHERE EXTRACT(HOUR FROM starttime::TIME) = 1 
GROUP BY start_station_id, starttime
ORDER BY avgduration ASC limit 1;'''
table = get_data(query)
table
# Out:
#                 starttime  start_station_id  avgduration
# 0  2015-02-03 01:25:00+00               316         77.0
